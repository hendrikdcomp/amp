# %% [markdown]
# # Tarefa 01

# %% [markdown]
# ## Classificação com `mxnet.gluon`
#
# Acompanhe a **seção 3.7 do livro-texto**, que mostra a implementação da Regressão Softmax usando `mxnet.gluon` para familiaridade das funções.
#
# Reutilize essa implementação para o famoso dataset **Iris**: https://archive.ics.uci.edu/ml/datasets/iris
#
# ![fig01.png](attachment:fig01.png)
#
# ![fig02.png](attachment:fig02.png)
#
# ![fig03.png](attachment:fig03.png)

# %%
### SUA IMPLEMENTAÇÃO AQUI

# Importar pacotes

# Carregar dataset e separar em treinamento e teste

# Inicializar parâmetros do modelo, incluindo tamanho do batch e taxa de aprendizado

# Executar treinamento

# Avaliar acurácia

# Testar previsão
